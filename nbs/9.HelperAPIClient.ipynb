# %%
import setup
setup.init_django()

# %%
import helpers.clients as helper_clients

# %%
dataset_a = helper_clients.AlphaVantageAPIClient()

# %%
dataset_b = helper_clients.PolygonAPIClient()

# %%
dataset_b = helper_clients.PolygonAPIClient()

# %%
dataset_a.get_stock_data()
# Out:
# [{'open_price': Decimal('184.2237'),
#   'close_price': Decimal('184.1345'),
#   'high_price': Decimal('184.2237'),
#   'low_price': Decimal('184.1047'),
#   'number_of_trades': None,
#   'volume': Decimal('2358'),
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.0551'),
#   'close_price': Decimal('184.0849'),
#   'high_price': Decimal('184.2039'),
#   'low_price': Decimal('184.0551'),
#   'number_of_trades': None,
#   'volume': Decimal('200'),
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('183.9758'),
#   'close_price': Decimal('184.0155'),
#   'high_price': Decimal('184.2039'),
#   'low_price': Decimal('183.9758'),
#   'number_of_trades': None,
#   'volume': Decimal('4017'),
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('183.9659'),
# ...
